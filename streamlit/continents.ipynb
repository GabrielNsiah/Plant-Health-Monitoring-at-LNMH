# %%
from base_script import return_merged_df
import pandas as pd
return_merged_df()


def get_info_by_continent(cursor: 'cursor', continent: int) -> pd.DataFrame:
    """Get a table of the total sales per truck or for a specific truck if provided."""
    if continent:
        cursor.execute(
            "SELECT soil_moisture FROM 
        )
    else:
        cursor.execute(
            "SELECT truck_name, COUNT(*) AS sales_count "
            "FROM truck AS t "
            "JOIN transaction AS tr ON t.truck_id = tr.truck_id "
            "GROUP BY truck_name;"
        )
    result: pd.DataFrame = cursor.fetch_dataframe()
    return result

get_info_by_continent()
# Out:
#     recording_id  plant_id         last_watered  soil_moisture  temperature  \
# 0             46        49  2024-11-28 14:02:15      29.717668     9.352769
# 1             47        50  2024-11-28 14:03:04      30.036929    13.137114
# 2             45        48  2024-11-28 14:31:09      31.069352    14.877861
# 3             44        47  2024-11-28 13:30:18      -6.049341    13.325786
# 4             43        46  2024-11-28 14:12:39      33.984884    13.287486
# 5             42        45  2024-11-28 14:04:23      30.186486    19.172736
# 6             41        44  2024-11-28 13:32:40      29.370872     9.539323
# 7             40        42  2024-11-28 14:49:43      32.948383     9.841084
# 8             38        40  2024-11-28 14:05:38      33.355544     9.050226
# 9             39        41  2024-11-28 13:45:13      31.590714    11.715961
# 10            37        39  2024-11-28 14:18:23      29.011468    13.372963
# ...
